# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-class-notes/blob/main/danl_210_note_12_2024_0307.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")
emp
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")

mean_salary = emp['Salary'].mean()
emp['Salary'] = emp['Salary'].fillna(mean_salary)

emp = emp.astype(
    {
        "Gender":"category",
        "Start Date":"datetime64",
        "Mgmt":"bool",
        "Team":"category"
        }
)
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 27.0+ KB

# %%
emp["Start Date"].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000     True
# Name: Start Date, Length: 1001, dtype: bool

# %% [markdown]
# Q. How can we pull out employees with non-missing Team values?

# %%
emp[ emp["Team"].notna() ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 957 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  899 non-null    object
#  1   Gender      815 non-null    category
#  2   Start Date  956 non-null    datetime64[ns]
#  3   Salary      957 non-null    float64
#  4   Mgmt        957 non-null    bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 33.2+ KB

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 27.0+ KB

# %%
emp['Team'].isna().sum()
# Out:
# 44

# %%
emp['Team'].value_counts(dropna=False)
# Out:
# IT              106
# Finance         102
# Business Dev    101
# Marketing        98
# Product          95
# Sales            94
# Engineering      92
# HR               91
# Distribution     90
# Legal            88
# NaN              44
# Name: Team, dtype: int64

# %%
emp.dropna()
# Out:
#     First Name  Gender Start Date         Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06   90655.528529   True     Marketing
# 4        Larry    Male 1998-01-24  101004.000000   True            IT
# 5       Dennis    Male 1987-04-18  115163.000000  False         Legal
# 6         Ruby  Female 1987-08-17   65476.000000   True       Product
# 8       Angela  Female 2005-11-22   95570.000000   True   Engineering
# ..         ...     ...        ...            ...    ...           ...
# 994     George    Male 2013-06-21   98874.000000   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.000000  False       Finance
# 997    Russell    Male 2013-05-20   96914.000000  False       Product
# 998      Larry    Male 2013-04-20   60500.000000  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.000000   True         Sales
#
# [762 rows x 6 columns]

# %%
emp.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 762 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  762 non-null    object
#  1   Gender      762 non-null    category
#  2   Start Date  762 non-null    datetime64[ns]
#  3   Salary      762 non-null    float64
#  4   Mgmt        762 non-null    bool
#  5   Team        762 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 26.5+ KB

# %%
emp.dropna(how = "all").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 27.0+ KB

# %%
emp.dropna(how = "any").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 762 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  762 non-null    object
#  1   Gender      762 non-null    category
#  2   Start Date  762 non-null    datetime64[ns]
#  3   Salary      762 non-null    float64
#  4   Mgmt        762 non-null    bool
#  5   Team        762 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 26.5+ KB

# %%
emp.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 762 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  762 non-null    object
#  1   Gender      762 non-null    category
#  2   Start Date  762 non-null    datetime64[ns]
#  3   Salary      762 non-null    float64
#  4   Mgmt        762 non-null    bool
#  5   Team        762 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 26.5+ KB

# %%
emp.dropna(subset = ["Gender"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 854 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  794 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  853 non-null    datetime64[ns]
#  3   Salary      854 non-null    float64
#  4   Mgmt        854 non-null    bool
#  5   Team        815 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 29.7+ KB

# %%
emp.dropna(subset = ["Start Date", "Salary"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  932 non-null    object
#  1   Gender      853 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        999 non-null    bool
#  5   Team        956 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 34.6+ KB

# %%
emp.dropna(thresh = 4).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  998 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        999 non-null    bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 34.6+ KB

# %%
emp.dropna(thresh = 2).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 27.0+ KB

# %%
emp[["Team"]]
# Out:
#               Team
# 0        Marketing
# 1              NaN
# 2          Finance
# 3          Finance
# 4               IT
# ...            ...
# 996        Finance
# 997        Product
# 998   Business Dev
# 999          Sales
# 1000           NaN
#
# [1001 rows x 1 columns]

# %%
emp["Team"].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
emp["Team"].duplicated(keep = "first")
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# Name: Team, Length: 1001, dtype: bool

# %%
emp["Team"].duplicated(keep = "last")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
emp
# Out:
#      First Name  Gender Start Date         Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06   90655.528529   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.000000   True           NaN
# 2         Maria  Female        NaT  130590.000000  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.000000   True       Finance
# 4         Larry    Male 1998-01-24  101004.000000   True            IT
# ...         ...     ...        ...            ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.000000  False       Finance
# 997     Russell    Male 2013-05-20   96914.000000  False       Product
# 998       Larry    Male 2013-04-20   60500.000000  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.000000   True         Sales
# 1000        NaN     NaN        NaT   90655.528529   True           NaN
#
# [1001 rows x 6 columns]

# %%
~emp["Team"].duplicated()
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: Team, Length: 1001, dtype: bool

# %%
emp.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), float64(1), object(1)
# memory usage: 34.7+ KB

# %%
# Sample DataFrame with duplicate observations
data = {
    'Name': ['John', 'Anna', 'John', 'Mike', 'Anna'],
    'Age': [28, 23, 28, 32, 23],
    'City': ['New York', 'Paris', 'New York', 'London', 'Paris']
}

# pd.DataFrame( Series, List, or Dict ) creates a DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   23     Paris
# 2  John   28  New York
# 3  Mike   32    London
# 4  Anna   23     Paris

# %%
df.drop_duplicates()
# Out:
#    Name  Age      City
# 0  John   28  New York
# 1  Anna   23     Paris
# 3  Mike   32    London

# %%
emp.drop_duplicates(subset = ["Team"])
# Out:
#    First Name  Gender Start Date         Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06   90655.528529   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.000000   True           NaN
# 2       Maria  Female        NaT  130590.000000  False       Finance
# 4       Larry    Male 1998-01-24  101004.000000   True            IT
# 5      Dennis    Male 1987-04-18  115163.000000  False         Legal
# 6        Ruby  Female 1987-08-17   65476.000000   True       Product
# 8      Angela  Female 2005-11-22   95570.000000   True   Engineering
# 9     Frances  Female 2002-08-08  139852.000000   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.000000   True            HR
# 13       Gary    Male 2008-01-27  109831.000000  False         Sales
# 40    Michael    Male 2008-10-10   99283.000000   True  Distribution

# %%
len(emp['Team'].value_counts(dropna=False))
# Out:
# 11

# %%
len(emp['Gender'].value_counts(dropna=False))
# Out:
# 3

# %%
emp.drop_duplicates(subset = ["Gender", "Team"])
# Out:
#     First Name  Gender Start Date         Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06   90655.528529   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.000000   True           NaN
# 2        Maria  Female        NaT  130590.000000  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.000000   True       Finance
# 4        Larry    Male 1998-01-24  101004.000000   True            IT
# 5       Dennis    Male 1987-04-18  115163.000000  False         Legal
# 6         Ruby  Female 1987-08-17   65476.000000   True       Product
# 8       Angela  Female 2005-11-22   95570.000000   True   Engineering
# 9      Frances  Female 2002-08-08  139852.000000   True  Business Dev
# 10      Louise  Female 1980-08-12   63241.000000   True           NaN
# 11       Julie  Female 1997-10-26  102508.000000   True         Legal
# 12     Brandon    Male 1980-12-01  112807.000000   True            HR
# ...

# %%
emp.drop_duplicates(subset = ["Team"])
# Out:
#    First Name  Gender Start Date         Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06   90655.528529   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.000000   True           NaN
# 2       Maria  Female        NaT  130590.000000  False       Finance
# 4       Larry    Male 1998-01-24  101004.000000   True            IT
# 5      Dennis    Male 1987-04-18  115163.000000  False         Legal
# 6        Ruby  Female 1987-08-17   65476.000000   True       Product
# 8      Angela  Female 2005-11-22   95570.000000   True   Engineering
# 9     Frances  Female 2002-08-08  139852.000000   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.000000   True            HR
# 13       Gary    Male 2008-01-27  109831.000000  False         Sales
# 40    Michael    Male 2008-10-10   99283.000000   True  Distribution

# %%
emp.drop_duplicates(subset = ["Team"], keep = "last")
# Out:
#      First Name  Gender Start Date         Salary   Mgmt          Team
# 988       Alice  Female 2004-10-05   47638.000000  False            HR
# 989      Justin     NaN 1991-02-10   38344.000000  False         Legal
# 990       Robin  Female 1987-07-24  100765.000000   True            IT
# 993        Tina  Female 1997-05-15   56450.000000   True   Engineering
# 994      George    Male 2013-06-21   98874.000000   True     Marketing
# 995       Henry     NaN 2014-11-23  132483.000000  False  Distribution
# 996     Phillip    Male 1984-01-31   42392.000000  False       Finance
# 997     Russell    Male 2013-05-20   96914.000000  False       Product
# 998       Larry    Male 2013-04-20   60500.000000  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.000000   True         Sales
# 1000        NaN     NaN        NaT   90655.528529   True           NaN

# %%
emp.drop_duplicates(subset = ["Team"], keep = False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Salary, Mgmt, Team]
# Index: []

# %%
emp["Team"].value_counts(dropna=False)
# Out:
# IT              106
# Finance         102
# Business Dev    101
# Marketing        98
# Product          95
# Sales            94
# Engineering      92
# HR               91
# Distribution     90
# Legal            88
# NaN              44
# Name: Team, dtype: int64

# %%
emp.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 33        Jean  Female 1993-12-18  119082.0  False  Business Dev
# 190      Carol  Female 1996-03-19   57783.0  False       Finance
# 291      Tammy  Female 1984-11-11  132839.0   True            IT
# 495     Eugene    Male 1984-05-24   81077.0  False         Sales
# 688      Brian    Male 2007-04-07   93901.0   True         Legal
# 832      Keith    Male 2003-02-12  120672.0  False         Legal
# 887      David    Male 2009-12-05   92242.0  False         Legal

# %%
emp.query("`First Name` == 'David' ")
# Out:
#     First Name Gender Start Date   Salary   Mgmt   Team
# 887      David   Male 2009-12-05  92242.0  False  Legal

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")

cond = ( emp["First Name"] == 'Douglas' ) & (emp["Gender"] == 'Male')
emp[cond]
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 0      Douglas   Male     8/6/93       NaN   True    Marketing
# 217    Douglas   Male     9/3/99   83341.0   True           IT
# 322    Douglas   Male     1/8/02   41428.0  False      Product
# 835    Douglas   Male     8/4/07  132175.0  False  Engineering

# %%
emp.drop_duplicates(subset = ["Gender", "Team"])
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male     8/6/93       NaN   True     Marketing
# 1       Thomas    Male    3/31/96   61933.0   True           NaN
# 2        Maria  Female        NaN  130590.0  False       Finance
# 3        Jerry     NaN     3/4/05  138705.0   True       Finance
# 4        Larry    Male    1/24/98  101004.0   True            IT
# 5       Dennis    Male    4/18/87  115163.0  False         Legal
# 6         Ruby  Female    8/17/87   65476.0   True       Product
# 8       Angela  Female   11/22/05   95570.0   True   Engineering
# 9      Frances  Female     8/8/02  139852.0   True  Business Dev
# 10      Louise  Female    8/12/80   63241.0   True           NaN
# 11       Julie  Female   10/26/97  102508.0   True         Legal
# 12     Brandon    Male    12/1/80  112807.0   True            HR
# 13        Gary    Male    1/27/08  109831.0  False         Sales
# ...

# %% [markdown]
# # Classwork 6 Q7-8
#
# ## Q7

# %%
netflix = pd.read_csv("https://bcdanl.github.io/data/netflix-2019.csv")
netflix
# Out:
#                       title        director date_added     type
# 0               Alias Grace             NaN   3-Nov-17  TV Show
# 1            A Patch of Fog  Michael Lennox  15-Apr-17    Movie
# 2                  Lunatics             NaN  19-Apr-19  TV Show
# 3                 Uriyadi 2     Vijay Kumar   2-Aug-19    Movie
# 4         Shrek the Musical     Jason Moore  29-Dec-13    Movie
# ...                     ...             ...        ...      ...
# 5832            The Pursuit     John Papola   7-Aug-19    Movie
# 5833       Hurricane Bianca   Matt Kugelman   1-Jan-17    Movie
# 5834           Amar's Hands  Khaled Youssef  26-Apr-19    Movie
# 5835  Bill Nye: Science Guy  Jason Sussberg  25-Apr-18    Movie
# 5836           Age of Glory             NaN        NaN  TV Show
#
# [5837 rows x 4 columns]

# %%
netflix.dropna(subset = ["director"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3936 entries, 1 to 5835
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       3936 non-null   object
#  1   director    3936 non-null   object
#  2   date_added  3901 non-null   object
#  3   type        3936 non-null   object
# dtypes: object(4)
# memory usage: 153.8+ KB

# %% [markdown]
# # Q8
#
# Identify the days when Netflix added only one movie to its catalog.

# %%
netflix['type'].value_counts(dropna=False)
# Out:
# Movie      3939
# TV Show    1898
# Name: type, dtype: int64

# %%
netflix[ (netflix['type'] == "Movie") | (netflix['date_added'].notna())  ]

# %%
(
    netflix
    .astype({'date_added':'datetime64'})[ (netflix['type'] == "Movie") & (netflix['date_added'].notna())  ]
    .drop_duplicates(subset = ['date_added'], keep = False)[['date_added']]
    .value_counts(dropna=False)
    .shape
)
# Out:
# (425,)

# %% [markdown]
# # Python Functions

# %%
def my_half(x):
  return x / 2

# %%
my_half(2) # 2 / 2
# Out:
# 1.0

# %%
my_half(3) # 3 / 2
# Out:
# 1.5

# %%
equiv_my_half = lambda x: x/2

# %%
equiv_my_half(2)
# Out:
# 1.0
