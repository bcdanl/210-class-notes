# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-class-notes/blob/main/danl_210_note_14_2024_0321.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

fortune1000 = pd.read_csv("https://bcdanl.github.io/data/fortune_2023.csv")

varlist = ['Company', 'Revenues_M', 'Profits_M', 'Number_of_employees', 'Sector', 'Industry']
fortune = fortune1000[varlist]

# %%
fortune
# Out:
#                         Company  Revenues_M  Profits_M  Number_of_employees  \
# 0                       Walmart      611289      11680              2100000
# 1                        Amazon      513983      -2722              1541000
# 2                   Exxon Mobil      413680      55740                62000
# 3                         Apple      394328      99803               164000
# 4            UnitedHealth Group      324162      20120               400000
# ..                          ...         ...        ...                  ...
# 995               TTEC Holdings        2444        103                69400
# 996             ProFrac Holding        2426         92                 3664
# 997            Summit Materials        2413        272                 4800
# 998              Teladoc Health        2407     -13660                 5208
# 999  Alliance Resource Partners        2407        577                 3371
#
# ...

# %%
fortune['Sector'].nunique()
# Out:
# 21

# %%
fortune.shape[0] # the number of obs.
# Out:
# 1000

# %%
fortune.shape[1] # the number of vars.
# Out:
# 6

# %%
fortune.size
# Out:
# 6000

# %%
(
    fortune
    .groupby("Sector")
    .size()
)
# Out:
# Sector
# Aerospace & Defense               16
# Apparel                           16
# Business Services                 52
# Chemicals                         28
# Energy                           115
# Engineering & Construction        31
# Financials                       161
# Food & Drug Stores                 9
# Food, Beverages & Tobacco         33
# Health Care                       80
# Hotels, Restaurants & Leisure     28
# Household Products                20
# Industrials                       49
# Materials                         48
# Media                             28
# Motor Vehicles & Parts            18
# Retailing                         72
# Technology                       117
# Telecommunications                 9
# Transportation                    39
# Wholesalers                       31
# dtype: int64

# %%
sectors = fortune.groupby("Sector")

# %%
sectors.sum()
# Out:
# <ipython-input-13-089e07073fd5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.sum()
#                                Revenues_M  Profits_M  Number_of_employees
# Sector
# Aerospace & Defense                350542      18892               901735
# Apparel                            128081      11605               315680
# Business Services                  426102      39726              1616385
# Chemicals                          329184      41516               524475
# Energy                            2685527     310339               927799
# Engineering & Construction         284591      25938               481716
# Financials                        3100823     281866              3825347
# Food & Drug Stores                 452715      11304              1256627
# ...

# %%
sectors.mean()
# Out:
# <ipython-input-14-c53551675e33>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.mean()
#                                  Revenues_M    Profits_M  Number_of_employees
# Sector
# Aerospace & Defense            21908.875000  1180.750000         56358.437500
# Apparel                         8005.062500   725.312500         19730.000000
# Business Services               8194.269231   763.961538         31084.326923
# Chemicals                      11756.571429  1482.714286         18731.250000
# Energy                         23352.408696  2698.600000          8067.817391
# Engineering & Construction      9180.354839   836.709677         15539.225806
# Financials                     19259.770186  1750.720497         23759.919255
# ...

# %%
sectors

# %%
sectors['Revenues_M']

# %%
sectors[ ['Revenues_M'] ].sum()
# Out:
#                                Revenues_M
# Sector
# Aerospace & Defense                350542
# Apparel                            128081
# Business Services                  426102
# Chemicals                          329184
# Energy                            2685527
# Engineering & Construction         284591
# Financials                        3100823
# Food & Drug Stores                 452715
# Food, Beverages & Tobacco          683802
# Health Care                       2932057
# Hotels, Restaurants & Leisure      216762
# Household Products                 240986
# Industrials                        546698
# Materials                          460008
# Media                              315721
# Motor Vehicles & Parts             549005
# Retailing                         2553636
# Technology                        2386944
# Telecommunications                 488030
# Transportation                     629263
# Wholesalers                        513741

# %%
sectors[ ['Revenues_M'] ].max()
# Out:
#                                Revenues_M
# Sector
# Aerospace & Defense                 67074
# Apparel                             46710
# Business Services                   29310
# Chemicals                           56902
# Energy                             413680
# Engineering & Construction          33671
# Financials                         302089
# Food & Drug Stores                 148258
# Food, Beverages & Tobacco          101556
# Health Care                        324162
# Hotels, Restaurants & Leisure       32250
# Household Products                  80187
# Industrials                         76555
# Materials                           41513
# Media                               82722
# Motor Vehicles & Parts             158057
# Retailing                          611289
# Technology                         394328
# Telecommunications                 136835
# Transportation                     100338
# Wholesalers                         68636

# %%
sectors[ ['Revenues_M'] ].min()
# Out:
#                                Revenues_M
# Sector
# Aerospace & Defense                  2557
# Apparel                              2631
# Business Services                    2481
# Chemicals                            2549
# Energy                               2407
# Engineering & Construction           2670
# Financials                           2453
# Food & Drug Stores                   3578
# Food, Beverages & Tobacco            3933
# Health Care                          2407
# Hotels, Restaurants & Leisure        2526
# Household Products                   2773
# Industrials                          2514
# Materials                            2413
# Media                                2453
# Motor Vehicles & Parts               2502
# Retailing                            2537
# Technology                           2444
# Telecommunications                   5413
# Transportation                       2641
# Wholesalers                          2613

# %%
sectors["Revenues_M"].agg('sum')
# Out:
# Sector
# Aerospace & Defense               350542
# Apparel                           128081
# Business Services                 426102
# Chemicals                         329184
# Energy                           2685527
# Engineering & Construction        284591
# Financials                       3100823
# Food & Drug Stores                452715
# Food, Beverages & Tobacco         683802
# Health Care                      2932057
# Hotels, Restaurants & Leisure     216762
# Household Products                240986
# Industrials                       546698
# Materials                         460008
# Media                             315721
# Motor Vehicles & Parts            549005
# Retailing                        2553636
# Technology                       2386944
# Telecommunications                488030
# Transportation                    629263
# Wholesalers                       513741
# Name: Revenues_M, dtype: int64

# %%
sectors["Revenues_M"].sum()
# Out:
# Sector
# Aerospace & Defense               350542
# Apparel                           128081
# Business Services                 426102
# Chemicals                         329184
# Energy                           2685527
# Engineering & Construction        284591
# Financials                       3100823
# Food & Drug Stores                452715
# Food, Beverages & Tobacco         683802
# Health Care                      2932057
# Hotels, Restaurants & Leisure     216762
# Household Products                240986
# Industrials                       546698
# Materials                         460008
# Media                             315721
# Motor Vehicles & Parts            549005
# Retailing                        2553636
# Technology                       2386944
# Telecommunications                488030
# Transportation                    629263
# Wholesalers                       513741
# Name: Revenues_M, dtype: int64

# %%
fortune.columns
# Out:
# Index(['Company', 'Revenues_M', 'Profits_M', 'Number_of_employees', 'Sector',
#        'Industry'],
#       dtype='object')

# %%
(
    sectors.
    agg(
        revenue_max = ("Revenues_M", "max"),
        profit_min = ("Profits_M", 'min'),
        n_emp_mean = ("Number_of_employees", 'mean')
    )
)
# Out:
#                                revenue_max  profit_min     n_emp_mean
# Sector
# Aerospace & Defense                  67074       -4935   56358.437500
# Apparel                              46710        -188   19730.000000
# Business Services                    29310      -16720   31084.326923
# Chemicals                            56902       -1871   18731.250000
# Energy                              413680       -1227    8067.817391
# Engineering & Construction           33671        -210   15539.225806
# Financials                          302089      -22819   23759.919255
# Food & Drug Stores                  148258        -539  139625.222222
# Food, Beverages & Tobacco           101556        -175   34754.393939
# Health Care                         324162      -13660   43184.000000
# Hotels, Restaurants & Leisure        32250       -2828   78075.250000
# Household Products                   80187        -232   26203.350000
# ...

# %%
sectors[["Revenues_M"]].agg('sum')
# Out:
#                                Revenues_M
# Sector
# Aerospace & Defense                350542
# Apparel                            128081
# Business Services                  426102
# Chemicals                          329184
# Energy                            2685527
# Engineering & Construction         284591
# Financials                        3100823
# Food & Drug Stores                 452715
# Food, Beverages & Tobacco          683802
# Health Care                       2932057
# Hotels, Restaurants & Leisure      216762
# Household Products                 240986
# Industrials                        546698
# Materials                          460008
# Media                              315721
# Motor Vehicles & Parts             549005
# Retailing                         2553636
# Technology                        2386944
# Telecommunications                 488030
# Transportation                     629263
# Wholesalers                        513741

# %% [markdown]
# # Classwork 7 - Q1-Q6

# %%
cereal = pd.read_csv('https://bcdanl.github.io/data/cereals_oatmeal.csv')
cereal
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 71                    Triples   General Mills  Cold       110    0.0       3
# 72                       Trix   General Mills  Cold       110    0.0      12
# 73                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 74                   Wheaties   General Mills  Cold       100    3.0       3
# 75        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
# [76 rows x 6 columns]

# %% [markdown]
# ## Q1
# Group the cereals, using the Manufacturer variable.

# %%
cereal_mf = (
    cereal
    .groupby("Manufacturer")
)

cereal_mf

# %% [markdown]
# ## Q2
# Determine the total number of groups, and the number of cereals per group.

# %%
# the total number of groups
len(cereal_mf)
cereal['Manufacturer'].nunique()
# Out:
# 6

# %%
# the number of cereals per group
df = (
    cereal_mf
    .size()
    .to_frame()
    # .rename(columns = {0:"n"})
)
df.columns = ['n']
df
# Out:
#                  n
# Manufacturer
# General Mills   22
# Kellogg's       23
# Nabisco          6
# Post             9
# Quaker Oats      8
# Ralston Purina   8

# %% [markdown]
# ## Q3
#
# Extract the cereals that belong to the manufacturer "Kellogg's".

# %%
cereal_mf.get_group("Kellogg's")[['Name']]
# Out:
#                            Name
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 6                   Apple Jacks
# 16                  Corn Flakes
# 17                    Corn Pops
# 19           Cracklin' Oat Bran
# 21                      Crispix
# 24                  Froot Loops
# 25               Frosted Flakes
# 26          Frosted Mini-Wheats
# 28                Fruitful Bran
# 38  Just Right Crunchy  Nuggets
# 39       Just Right Fruit & Nut
# 45         Mueslix Crispy Blend
# 47             Nut&Honey Crunch
# 48    Nutri-Grain Almond-Raisin
# 49            Nutri-grain Wheat
# 52                   Product 19
# 57                  Raisin Bran
# 59               Raisin Squares
# 61                Rice Krispies
# 65                       Smacks
# 66                    Special K

# %% [markdown]
# ## Q4
# Calculate the average of values in the Calories, Fiber, and Sugars variables for each manufacturer.

# %%
(
    cereal_mf
    .mean()
    .round(2)
)
# Out:
# <ipython-input-41-44b74f9c7cd0>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .mean()
#                 Calories  Fiber  Sugars
# Manufacturer
# General Mills     111.36   1.27    7.95
# Kellogg's         108.70   2.74    7.57
# Nabisco            86.67   4.00    1.83
# Post              108.89   2.78    8.78
# Quaker Oats        95.00   1.34    5.25
# Ralston Purina    115.00   1.88    6.12

# %% [markdown]
# ## Q5
# Find the maximum value in the Sugars variable for each manufacturer.

# %%
(
    cereal_mf[['Sugars']]
    .max()
)
# Out:
#                 Sugars
# Manufacturer
# General Mills       14
# Kellogg's           15
# Nabisco              6
# Post                15
# Quaker Oats         12
# Ralston Purina      11

# %% [markdown]
# ## Q6
# Find the minimum value in the Fiber variable for each manufacturer.

# %%
(
    cereal_mf
    .agg(
        fiber_min = ('Fiber', 'min')
    )
)
# Out:
#                 fiber_min
# Manufacturer
# General Mills         0.0
# Kellogg's             0.0
# Nabisco               1.0
# Post                  0.0
# Quaker Oats           0.0
# Ralston Purina        0.0

# %% [markdown]
# # transform()

# %%
sectors['Revenues_M'].transform('min')
# Out:
# 0      2537
# 1      2537
# 2      2407
# 3      2444
# 4      2407
#        ...
# 995    2444
# 996    2407
# 997    2413
# 998    2407
# 999    2407
# Name: Revenues_M, Length: 1000, dtype: int64

# %%
fortune.shape[0]
# Out:
# 1000

# %%
fortune_df = fortune

# %%
fortune_df['revenue_min'] = sectors['Revenues_M'].transform('min')

fortune_df
# Out:
# <ipython-input-48-6f3be16ccc31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fortune_df['revenue_min'] = sectors['Revenues_M'].transform('min')
#                         Company  Revenues_M  Profits_M  Number_of_employees  \
# 0                       Walmart      611289      11680              2100000
# 1                        Amazon      513983      -2722              1541000
# 2                   Exxon Mobil      413680      55740                62000
# 3                         Apple      394328      99803               164000
# 4            UnitedHealth Group      324162      20120               400000
# ..                          ...         ...        ...                  ...
# ...

# %%
sectors[['Profits_M']].transform('max')
# Out:
#      Profits_M
# 0        17105
# 1        17105
# 2        55740
# 3        99803
# 4        31372
# ..         ...
# 995      99803
# 996      55740
# 997       7607
# 998      31372
# 999      55740
#
# [1000 rows x 1 columns]

# %%
(
    fortune
    .assign(
        rev_min = sectors['Revenues_M'].transform('min'),
        profit_max = sectors['Profits_M'].transform('max')
    )
)
# Out:
#                         Company  Revenues_M  Profits_M  Number_of_employees  \
# 0                       Walmart      611289      11680              2100000
# 1                        Amazon      513983      -2722              1541000
# 2                   Exxon Mobil      413680      55740                62000
# 3                         Apple      394328      99803               164000
# 4            UnitedHealth Group      324162      20120               400000
# ..                          ...         ...        ...                  ...
# 995               TTEC Holdings        2444        103                69400
# 996             ProFrac Holding        2426         92                 3664
# 997            Summit Materials        2413        272                 4800
# 998              Teladoc Health        2407     -13660                 5208
# 999  Alliance Resource Partners        2407        577                 3371
#
# ...

# %% [markdown]
# # Classwork 7 - Q7
# Calculate a ‘Normalized_Sugars’ variable for each product by Manufacturer, where the normalization formula is
#
# $$\text{Normalized_Sugars}
# =
# \frac{Sugars
# −
# mean(Sugars)}
# {std(Sugars)}$$
#
# for each Manufacturer group. This formula adjusts the sugar content of each product by subtracting the mean sugar content of its manufacturer and then dividing by the standard deviation of the sugar content within its manufacturer.

# %%
cereal.shape[0]
# Out:
# 76

# %%
cereal_mf[['Sugars']].transform('mean')
# Out:
#       Sugars
# 0   1.833333
# 1   5.250000
# 2   7.565217
# 3   7.565217
# 4   6.125000
# ..       ...
# 71  7.954545
# 72  7.954545
# 73  6.125000
# 74  7.954545
# 75  7.954545
#
# [76 rows x 1 columns]

# %%
cereal = (
    cereal
    .assign(
        sugar_mean = cereal_mf[['Sugars']].transform('mean'),
        sugar_std = cereal_mf[['Sugars']].transform('std')
    )
)

cereal['Normalized_Sugars'] = ( cereal['Sugars'] - cereal['sugar_mean'] ) / cereal['sugar_std']

cereal
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars  \
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 71                    Triples   General Mills  Cold       110    0.0       3
# 72                       Trix   General Mills  Cold       110    0.0      12
# 73                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 74                   Wheaties   General Mills  Cold       100    3.0       3
# 75        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
#     sugar_mean  sugar_std  Normalized_Sugars
# ...

# %%
(
    cereal
    .assign(
        Normalized_Sugars2 = ( cereal['Sugars'] - cereal_mf['Sugars'].transform('mean') )
                                / cereal_mf['Sugars'].transform('std')
    )
)
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars  \
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 71                    Triples   General Mills  Cold       110    0.0       3
# 72                       Trix   General Mills  Cold       110    0.0      12
# 73                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 74                   Wheaties   General Mills  Cold       100    3.0       3
# 75        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
# ...

# %%
fortune = (
    fortune
    .sample( frac = 1 )
    .reset_index( drop = True )
)

fortune
# Out:
#                                   Company  Revenues_M  Profits_M  \
# 0             Service Corp. International        4109        565
# 1                               NewMarket        2765        280
# 2                       Primoris Services        4421        133
# 3                           Genuine Parts       22096       1183
# 4                                  Oracle       42440       6717
# ..                                    ...         ...        ...
# 995                                 Chewy       10099         49
# 996  Knight-Swift Transportation Holdings        7429        771
# 997             First Citizens BancShares        5549       1098
# 998                                   ATI        3836        131
# 999                      Antero Resources        7138       1899
#
#      Number_of_employees                      Sector  \
# 0                  21364           Business Services
# 1                   2058                   Chemicals
# ...

# %% [markdown]
# # Applying a Custom Operation to All Groups

# %%
sectors.sort_values('Revenues_M', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-1bcb4c55d374> in <cell line: 1>()
# ----> 1 sectors.sort_values('Revenues_M', ascending = False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     985             return self[attr]
#     986
# --> 987         raise AttributeError(
#     988             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'
